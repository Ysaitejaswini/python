# %%
# first how many userd important variables are there inside the function
# bill_amount,tip_amount what error will come

# %%
#WAP ask the user enter number
# and find square of the number
# m-1:write in normal ways
# m-2:write in function without arguements
# m-3:write in function with arguement



def square(number):

        print("the square of {} is{}".format(number,number*number))
square(7)
# Out:
# the square of 7 is49

# %%
def square():
    number=eval(input("enter a number:"))
    print("the square of {} is{}".format(number,number*number))
square()
# Out:
# enter a number:50
# the square of 50 is2500

# %%
# WAP ask there user
# get one random number
# enter a number
# compare these two numbers
# if both are same:print("you won")
# else:print(lost)

# write a normal way
# create a function with out arguements
# create a function with arguements


import random
random_num=random.randint(1,20)
num=eval(input("enter number:"))
if random_num==num:
    print("you won")
else:
    print("lost")
# Out:
# enter number:8
# lost

# %%
import random
def compare(num):
    random_num=random.randint(1,20)
    number=eval(input("enter a number enter:"))
    if random_num==num:
        print("you won")
    else:
        print("you lost because the random number is:",random_num)
compare(eval(input("enter number")))  # keyboard pass
# Out:
# enter number14
# enter a number enter:18
# you lost because the random number is: 7

# %%
import random
def compare(random_num,num):
    if random_num==num:
        print("you won")
    else:
        print("you lost because the random number is:",random_num)
value_random=random.randint(1,20)
value=eval(input("enter a number:"))
compare=(value_random,value)
# Out:
# enter a number:18

# %%
# step:1 import random
# step:2 function will defin: not give
# step:5 calling the function=======> step-2
#                                     print won/loss
# step:3 value_random
# step:4 value will get               ***ITS NOT WORKS***




import random
def compare(random_num,num):
    if random_num==num:
        print("you won")
    else:
        print("you lost because the random number is:",random_num)
compare(random.randint(1,20),
eval(input("enter number")))
# Out:
# enter number10
# you lost because the random number is: 5

# %%
# WAP ask the user enter salary
# ask the user enter tax prcentage
# calculate total tax to pay


def salary():
    salary=eval(input("enter a salary:"))
    tax_percentage=eval(input("enter a tax_percentage:"))
    print("the amount tax paid:",salary*tax_percentage/100)
salary()
# Out:
# enter a salary:100000
# enter a tax_percentage:5
# the amount tax paid: 5000.0

# %%
def tax_cal(salary,tax_per):
    total_tax=salary*tax_per/100
    print("the total tax is:",total_tax)
tax_cal(40000,4)
# Out:
# the total tax is: 1600.0

# %%
def tax_cal(salary,tax_per):
    total_tax=salary*tax_per/100
    print("the total tax is:",total_tax)
salary=eval(input("enter a salary"))
tax_percentage=eval(input("enter a tax_percentage"))
tax_cal(salary,tax_percentage)
# Out:
# enter a salary80000
# enter a tax_percentage80
# the total tax is: 64000.0

# %%
# default arguemants#


def tax_cal(salary,tax_per=20):
    total_tax=salary*tax_percentage/100
    print("the total tax is:",total_tax)
    
tax_cal(80000)
# Out:
# the total tax is: 64000.0

# %%
def avg(num1,num2,num3):
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(10,20,30)
# Out:
# the avg is: 20.0

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(10,20)
# Out:
# num1: 10
# num2: 20
# num3: 50
# the avg is: 26.666666666666668

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(10,20)
# Out:
#   Cell In[62], line 1
#     def avg(num1,num2=500,num3):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    num3=800
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300,600)   


# while defining function: num3=50
# while you are calling function num3=60
# after enter inside the fun num3=800
# Out:
# num1: 200
# num2: 300
# num3: 600
# the avg is: 433.3333333333333

# %% [markdown]
# .with out arguements
# .with arguements
# .default arguements

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
complex()    # not provide default
# Out:
# 0j

# %%
complex(7)
# Out:
# (7+0j)

# %% [markdown]
# . python

# %%
#WAP ask the user to find area of circle
#formulae: pi*radius*radius
# import math,math.pi
# basic method
# with out arguements
# with arguements
# default arguements


import math
pii=math.pi
r=eval(input("enter the radius"))
area1=round(pii*r*r,2)
print("the area of circle is:",area1)
# Out:
# enter the radius30
# the area of circle is: 2827.43

# %%
# M-1: with out arguements.keyboard pass
# you need to provide arguement value before call the function anywhere
# r=eval(input("enter radius"))
import math
def area_of_circle(r):
    pii=math.pi
    area1=round(pii*r*r,2)
    print("the area of circle is:",area1)
    r=eval(input("enter a radius"))
area_of_circle(30)
# Out:
# the area of circle is: 2827.43
# enter a radius30

# %%
# m-3: default arguements
import math
def area_of_circle(pii,r=20)
    area1=round(pii*r*r,2)
    print("thr area of circle is:",area1)
pii=math.pi
area_of_circle(pii)
# Out:
#   Cell In[7], line 3
#     def area_of_circle(pii,r=20)
#                                 ^
# SyntaxError: expected ':'

# %%
import math
def area_of_circle():
    pii=math.pi
    r=eval(input("enter the radius"))
    area11=round(pii*r*r,2)
    print("the area of circle is:",area11)
area_of_circle()
# Out:
# enter the radius30
# the area of circle is: 2827.43

# %%
import math
def area_of_circle():
    pii=math.pi
    r=eval(input("enter the radius"))
    area11=round(pii*r*r,2)
    print("the area of circle is:",area11)
    return(area1,pii)
Area,pi=area_of_circle()
print(Area)
print(pi)
# Out:
# enter the radius30
# the area of circle is: 2827.43
# 2827.43
# 3.141592653589793

# %%
# ask the user enter 3 numbers
# find the sum and average
# return the average value and sum both


def sum_avg():
    number1=eval(input("enter a number1"))
    number2=eval(input("enter a number2"))
    number3=eval(input("enter a number3"))
    sum=number1+number2+number3
    avg=sum/3
    print("sum:",sum)
    print("avg:",avg)
    return(sum,avg)
sum_avg()
# Out:
# enter a number110
# enter a number220
# enter a number330
# sum: 60
# avg: 20.0
# (60, 20.0)

# %%
def sum_avg(n1,n2,n3):
    sum=(n+n2+n3)
    avg=sum/3

# %%
# Find the biggest number of 3 numbers
# take three numbers
# and find the biggest number
# and return that number

# if num1>num2 and num1>num3 : num1

# elif num2>num3:  num2

# else: num3

# first write the normal code
# then create the function
# return the value



def greater(n1,n2,n3):
    if n1>n2 and n1>n3:
        print('n1 is greater'.format(n1))
        return(n1)
    elif n2>n3:
        print("{} is greater".format(n2))
        return(n2)
    else:
        print("{} is greater".format(n3))
        return(n3)
greater(20,200,10)
# Out:
# 200 is greater
# 200

# %%
def add(a,b):
    return(a+b)
def sub(a,b):
    return(a-b)
def mul(a,b):
    return(a*b)
def div(a,b):
    return(a/b)
val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)
print(val_add,val_sub,val_mul,round(val_div,2))
# Out:
# 50 -10 600 0.67

# %%
def aggregate(a,b):
    return(a+b,a-b,a*b,a/b)
add,sub,mul,div=aggregate(30,50)
print(add,mul,sub,round(div,2))
# Out:
# 80 1500 -20 0.6

# %%
def add(a,b):return(a+b)
def sub(a,b):return(a-b)
def mul(a,b):return(a*b)
def div(a,b)
    return(a/b)
val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)
print(val_add,val_sub,val_mul,round(val_div,2))

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

# %%
local variables:
    the variables provided inside the function
global variables
    the variables provided outside the function

# %%
n1=10
n2=20
def addition():  # no need to provide inside brackets
    # no need to provide
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,n3))
addition()

# %%
def avg():  # inside the function(local variables)
    num1=20
    num2=30
    num3=40
    avg=(num1+num2+num3)/3
    print("the addition of {} and {} is {}:".format(num1,num2,num3,avg))
avg()
# Out:
# the addition of 20 and 30 is 40:

# %%
# outside the function(global variables)
num1=20
num2=30
num3=40
def avg():
    avg=(num1+num2+num3)/3
    print("the average of {} and {} is {}:".format(num1,num2.num3,avg))
avg()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       6     avg=(num1+num2+num3)/3
#       7     print("the average of {} and {} is {}:".format(num1,num2.num3,avg))
# ----> 8 avg()
#
# Cell In[3], line 7, in avg()
#       5 def avg():
#       6     avg=(num1+num2+num3)/3
# ----> 7     print("the average of {} and {} is {}:".format(num1,num2.num3,avg))
#
# AttributeError: 'int' object has no attribute 'num3'

# %%
n1=10
n2=30
def addition():
    num1=100
    num2=300
    add=n1+n2
    print("the addition of {} and {} is {}:".format(num1,num2,avg))
print(n1)
# Out:
# 10

# %%
n1=10
n2=20
def addition(n1=700):
    num2=200
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(500)
print(n1)
# Out:
# the addition of 500 and 20 is 520:
# 10

# %%
n1=10
n2=20
def addition(n1=800):
    num2=200
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(700)
print(n1)
# Out:
# the addition of 700 and 20 is 720:
# 10

# %%
def addition():
    num1=600
    num2=800
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition()
# Out:
# the addition of 10 and 20 is 30:

# %%
# we can not use local variable values outside the function
# untill unless with out return statement

# i want to use local variable outside the function,with out using return statement

# %%
global

# %%
n1=10
def update():
    n1=n1+100
    print("n1 value inside the function is:",n1)
updated()
print(n1)


# with out return n1,we need to get the updated value
# we need to use local variable outside the function,with out return

# %%
def value():
    global number1
    number1=10
    print(number1)
value()
print(number1)
# Out:
# 10
# 10

# %%
def value():
    global number1,number2
    number1=10
    number2=50               # it is very imp for interview question.
    print(number1)
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# 50

# %%
n_=10
def updated():
    n_=100
    n_=n_+100
    print("n1 value inside the function is:",n_)
update()
print(n_)
# Out:
# n1 value inside the function is: 200
# 10

# %%
n_=100
def updated():
    global n_
    n_=100
    n_=n_+100
    print("n1 value inside the function is:",n_)
update()   #200
print(n_)  #300
# Out:
# n1 value inside the function is: 200
# 100

# %%
n1=20
n2=30
def addition(n1):
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(500)

print(n2)   # i need to get n2 value 300,instead of 30
print(addition)  # i need to add value
# Out:
# the addition of 500 and 300 is 800
# 30
# <function addition at 0x0000022949FBB4C0>

# %%
def great():
    print("hello")
def name():
    print('python')
    
great()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
def name():
    print('python')
    greet()
name()

# step:1 define greet()
# step:2 define name()
# step:3 calling name()
# step:4 python
# step:5 calling greet()
# step:6 hello
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    name()
def name():    
    print('python')
    greet()

# %%
def greet():
    print("hello")
    name()
def name():
    print('python')  
    greet()
greet()    
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
print(3)

def fun1():
    print('hello')
    print('python')
    
print('hello')
def fun2():
    print('3+5')
    print(3+5)
    fun1()
    print('good')
print(10+10)
def fun3():
    fun1()
    fun2()
fun3()
# Out:
# 3
# hello
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
int()
# Out:
# 0

# %%
str()
# Out:
# ''

# %%
# create four functions
# def add(a+b):
#     print(a+b)
# sub
# mul
# div
# you need to provide some print statements
# if you want enter 1:addition operation will come
# if you want enter 2:subtract
# if you want enter 3:division
# if you want enter 4:multiplication
# operation=input("enter a number")
# a=eval(input())
# b=eval(input())
# if operation=='1':
# add(a,b)
# if operation=='2':
# sub(a,b)
# if operation=='3':
# mul(a,b)
# if operation=='4':
# div(a,b)

def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num=eval(input("enter a number:"))
    a=eval(input("enter a num1"))
    b=eval(input("enter a num2"))
    if num==1:
        add(a,b)
    elif num==2:
        sub(a,b)
    elif num==3:
        mul(a,b)
    else:
        div(a,b)
main()
# Out:
# enter a number:22
# enter a num133
# enter a num255
# 0.6
